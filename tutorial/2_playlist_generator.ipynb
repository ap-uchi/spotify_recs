# %% [markdown]
# # 2 - Generating a full playlist with your trained Random Forest Model
# ---------------
# In this notebook, we take the trained model in the last notebook to make a new playlist!

# %%
import pickle as pkl
import random
from typing import Iterable, Union

from dotenv import dotenv_values
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , roc_auc_score
from sklearn import tree
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Custom packages
import helpers as h
from helpers import Playlist, PlaylistCluster

# %%
# Set up Spotify API client credentials
config = dotenv_values('.env')
client_id = config["SPOTIFY_CLIENT_ID"]
client_secret = config["SPOTIFY_CLIENT_SECRET"]

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Load the trained random forest classifier from the previous notebook
with open('./trained_rf.pkl', 'rb') as f:
    rf_classifier = pkl.load(f)

# Load the playlist cluster from the previous notebook
with open('./playlist_cluster.pkl', 'rb') as f:
    PLC = pkl.load(f)

rb_playlist = PLC.playlist_list[0]
lnv_playlist = PLC.playlist_list[1]

# %% [markdown]
# Let's ask the random forest classifier if we should add a song to the playlist!

# %%
class Song():
    '''Access audio features of a Spotify song.'''

    def __init__(self, song_id:str=None, song_name:str=None, song_dict:dict=None) -> None:
        for ikwarg, kwarg in enumerate([song_id, song_name, song_dict]):
            if kwarg is not None:
                self.input = kwarg
                if ikwarg == 0:
                    self.id = self.input
                    self.attributes = sp.track(self.id)
                    self.name = self.attributes['name']
                elif ikwarg == 2:
                    self.id = self.get_info_from_dict(self.input, 'id')
                    self.name = self.get_info_from_dict(self.input, 'name')

                    
        self.audio_features = sp.audio_features(self.id)
        
        self.data = pd.DataFrame(data=self.audio_features).sort_index(axis='columns')
        # initialize like to none
        self.data['like'] = np.nan
        self.ml_likes = np.nan

        data_multiIndex = pd.MultiIndex.from_frame(pd.DataFrame({'id':[self.id], 'name':[self.name]}))
        self.data.index = data_multiIndex
        
        self.audio_feature_labels = self.data.columns

        ## ML specifically (e.g. random forest)
        self.ml_feature_labels = list(set(self.audio_feature_labels)-\
                {'type', 'id','uri','track_href','analysis_url','like'})
        self.ml_data = self.data.loc[:, self.ml_feature_labels].sort_index(axis='columns')

    def get_info_from_dict(self, track:dict, info_tag:str):
        '''Unnest information from raw_tracks dict.'''

        if info_tag in track['track'].keys():
            attributes = track['track'][info_tag] 
            return attributes

# %%
s = Song(song_dict=rb_playlist.raw_tracks[0])
s.data
# Out:
#                                              acousticness
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)        0.0735  \
#
#                                                                                   analysis_url
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)  https://api.spotify.com/v1/audio-analysis/5awN...  \
#
#                                              danceability  duration_ms
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)         0.781       201120  \
#
#                                              energy                      id
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)   0.814  5awNIWVrh2ISfvPd5IUZNh  \
#
#                                              instrumentalness  key  liveness
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)          0.000019    8    0.0565  \
#
#                                              loudness  mode  speechiness
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)    -2.437     1          0.1  \
#
#                                                tempo  time_signature
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)  124.028               4  \
#
#                                                                                     track_href
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)  https://api.spotify.com/v1/tracks/5awNIWVrh2IS...  \
#
#                                                        type
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)  audio_features  \
#
#                                                                               uri
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)  spotify:track:5awNIWVrh2ISfvPd5IUZNh  \
#
#                                              valence  like
# id                     name
# 5awNIWVrh2ISfvPd5IUZNh PTT (Paint The Town)    0.546   NaN

# %%
# Get a song from Spotify and its features
def grab_a_song():
    # Get a random search term or a random track ID
    search_term = random.choice(['love', 'happy', 'dance', 'rock', 'jazz'])
    results = sp.search(q=search_term, type='track', limit=50)

    # Get a random track from the search results
    track = random.choice(results['tracks']['items'])
    song = Song(track['id'])

    return song

# %%
s = grab_a_song()
s.ml_data
# Out:
#                                    acousticness  danceability  duration_ms
# id                     name
# 2woGHWgrFfjXAgdUsitbqr Happy Hour         0.162         0.616       199840  \
#
#                                    energy  instrumentalness  key  liveness
# id                     name
# 2woGHWgrFfjXAgdUsitbqr Happy Hour   0.835                 0    7    0.0977  \
#
#                                    loudness  mode  speechiness  tempo
# id                     name
# 2woGHWgrFfjXAgdUsitbqr Happy Hour    -4.277     1       0.0354  97.96  \
#
#                                    time_signature  valence
# id                     name
# 2woGHWgrFfjXAgdUsitbqr Happy Hour               4      0.8

# %%
rf_classifier.predict(s.ml_data)
# Out:
# array([1.])

# %% [markdown]
# We need a way to query a lot of random songs from Spotify to build a full playlist! Luckily Spotipy has a recommendations method that enables us to query Spotify based on target features.

# %%
rf_classifier.feature_names_in_
# Out:
# array(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'], dtype=object)

# %%
import scipy.stats as stats

# %%
stats.norm()

# %%
lnv_playlist.track_artists
# Out:
# [[{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#    'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#    'id': '20wkVLutqVOYrc0kxFs7rA',
#    'name': 'Daniel Caesar',
#    'type': 'artist',
#    'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6icQOAFXDZKsumw3YXyusw'},
#    'href': 'https://api.spotify.com/v1/artists/6icQOAFXDZKsumw3YXyusw',
#    'id': '6icQOAFXDZKsumw3YXyusw',
#    'name': 'Lil Yachty',
#    'type': 'artist',
#    'uri': 'spotify:artist:6icQOAFXDZKsumw3YXyusw'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Cp8WN4V8Tu4QJQwCN5Md4'},
#    'href': 'https://api.spotify.com/v1/artists/0Cp8WN4V8Tu4QJQwCN5Md4',
#    'id': '0Cp8WN4V8Tu4QJQwCN5Md4',
#    'name': 'BENEE',
#    'type': 'artist',
#    'uri': 'spotify:artist:0Cp8WN4V8Tu4QJQwCN5Md4'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX'},
#    'href': 'https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX',
#    'id': '5fMUXHkw8R8eOP2RNVYEZX',
#    'name': 'Diplo',
#    'type': 'artist',
#    'uri': 'spotify:artist:5fMUXHkw8R8eOP2RNVYEZX'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20wkVLutqVOYrc0kxFs7rA'},
#    'href': 'https://api.spotify.com/v1/artists/20wkVLutqVOYrc0kxFs7rA',
#    'id': '20wkVLutqVOYrc0kxFs7rA',
#    'name': 'Daniel Caesar',
#    'type': 'artist',
#    'uri': 'spotify:artist:20wkVLutqVOYrc0kxFs7rA'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#    'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#    'id': '1U1el3k54VvEUzo3ybLPlM',
#    'name': 'Kali Uchis',
#    'type': 'artist',
#    'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4N7IToHBlPXqlrXiv1Nij6'},
#    'href': 'https://api.spotify.com/v1/artists/4N7IToHBlPXqlrXiv1Nij6',
#    'id': '4N7IToHBlPXqlrXiv1Nij6',
#    'name': 'rei brown',
#    'type': 'artist',
#    'uri': 'spotify:artist:4N7IToHBlPXqlrXiv1Nij6'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq'},
#    'href': 'https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq',
#    'id': '3MZsBdqDrRTJihTHQrO6Dq',
#    'name': 'Joji',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MZsBdqDrRTJihTHQrO6Dq'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1tQu5TjcAK68fx8qrc8ZgF'},
#    'href': 'https://api.spotify.com/v1/artists/1tQu5TjcAK68fx8qrc8ZgF',
#    'id': '1tQu5TjcAK68fx8qrc8ZgF',
#    'name': 'SEBASTIAN PAUL',
#    'type': 'artist',
#    'uri': 'spotify:artist:1tQu5TjcAK68fx8qrc8ZgF'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1tQu5TjcAK68fx8qrc8ZgF'},
#    'href': 'https://api.spotify.com/v1/artists/1tQu5TjcAK68fx8qrc8ZgF',
#    'id': '1tQu5TjcAK68fx8qrc8ZgF',
#    'name': 'SEBASTIAN PAUL',
#    'type': 'artist',
#    'uri': 'spotify:artist:1tQu5TjcAK68fx8qrc8ZgF'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#    'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#    'id': '2h93pZq0e7k5yf4dywlkpM',
#    'name': 'Frank Ocean',
#    'type': 'artist',
#    'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#    'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#    'id': '2h93pZq0e7k5yf4dywlkpM',
#    'name': 'Frank Ocean',
#    'type': 'artist',
#    'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#    'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#    'id': '2h93pZq0e7k5yf4dywlkpM',
#    'name': 'Frank Ocean',
#    'type': 'artist',
#    'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/30yozRF4B2uaL6eDBsLH96'},
#    'href': 'https://api.spotify.com/v1/artists/30yozRF4B2uaL6eDBsLH96',
#    'id': '30yozRF4B2uaL6eDBsLH96',
#    'name': 'Myra Molloy',
#    'type': 'artist',
#    'uri': 'spotify:artist:30yozRF4B2uaL6eDBsLH96'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cxAeZbDhf2S8t544RIVIf'},
#    'href': 'https://api.spotify.com/v1/artists/1cxAeZbDhf2S8t544RIVIf',
#    'id': '1cxAeZbDhf2S8t544RIVIf',
#    'name': 'Gus Harvey',
#    'type': 'artist',
#    'uri': 'spotify:artist:1cxAeZbDhf2S8t544RIVIf'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/163tK9Wjr9P9DmM0AVK7lm'},
#    'href': 'https://api.spotify.com/v1/artists/163tK9Wjr9P9DmM0AVK7lm',
#    'id': '163tK9Wjr9P9DmM0AVK7lm',
#    'name': 'Lorde',
#    'type': 'artist',
#    'uri': 'spotify:artist:163tK9Wjr9P9DmM0AVK7lm'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TXiTMAJtmAIe8tpHrZBtZ'},
#    'href': 'https://api.spotify.com/v1/artists/2TXiTMAJtmAIe8tpHrZBtZ',
#    'id': '2TXiTMAJtmAIe8tpHrZBtZ',
#    'name': 'Marc Wavy',
#    'type': 'artist',
#    'uri': 'spotify:artist:2TXiTMAJtmAIe8tpHrZBtZ'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NZvixzsSefsNiIqXn0NDe'},
#    'href': 'https://api.spotify.com/v1/artists/4NZvixzsSefsNiIqXn0NDe',
#    'id': '4NZvixzsSefsNiIqXn0NDe',
#    'name': 'Maggie Rogers',
#    'type': 'artist',
#    'uri': 'spotify:artist:4NZvixzsSefsNiIqXn0NDe'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1DS9B5f4jcKRCqXI6fKDYY'},
#    'href': 'https://api.spotify.com/v1/artists/1DS9B5f4jcKRCqXI6fKDYY',
#    'id': '1DS9B5f4jcKRCqXI6fKDYY',
#    'name': 'A.G. Sully',
#    'type': 'artist',
#    'uri': 'spotify:artist:1DS9B5f4jcKRCqXI6fKDYY'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6pvrK6UpB0oSrfmEeUPFf5'},
#    'href': 'https://api.spotify.com/v1/artists/6pvrK6UpB0oSrfmEeUPFf5',
#    'id': '6pvrK6UpB0oSrfmEeUPFf5',
#    'name': 'Neeko Crowe',
#    'type': 'artist',
#    'uri': 'spotify:artist:6pvrK6UpB0oSrfmEeUPFf5'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AcfbTxwwz9q4dxJP9sZTI'},
#    'href': 'https://api.spotify.com/v1/artists/6AcfbTxwwz9q4dxJP9sZTI',
#    'id': '6AcfbTxwwz9q4dxJP9sZTI',
#    'name': 'Milo Korbenski',
#    'type': 'artist',
#    'uri': 'spotify:artist:6AcfbTxwwz9q4dxJP9sZTI'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2h93pZq0e7k5yf4dywlkpM'},
#    'href': 'https://api.spotify.com/v1/artists/2h93pZq0e7k5yf4dywlkpM',
#    'id': '2h93pZq0e7k5yf4dywlkpM',
#    'name': 'Frank Ocean',
#    'type': 'artist',
#    'uri': 'spotify:artist:2h93pZq0e7k5yf4dywlkpM'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5FxD8fkQZ6KcsSYupDVoSO'},
#    'href': 'https://api.spotify.com/v1/artists/5FxD8fkQZ6KcsSYupDVoSO',
#    'id': '5FxD8fkQZ6KcsSYupDVoSO',
#    'name': 'Omar Apollo',
#    'type': 'artist',
#    'uri': 'spotify:artist:5FxD8fkQZ6KcsSYupDVoSO'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2TXiTMAJtmAIe8tpHrZBtZ'},
#    'href': 'https://api.spotify.com/v1/artists/2TXiTMAJtmAIe8tpHrZBtZ',
#    'id': '2TXiTMAJtmAIe8tpHrZBtZ',
#    'name': 'Marc Wavy',
#    'type': 'artist',
#    'uri': 'spotify:artist:2TXiTMAJtmAIe8tpHrZBtZ'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3daREed4KlrtvohgJjSkJr'},
#    'href': 'https://api.spotify.com/v1/artists/3daREed4KlrtvohgJjSkJr',
#    'id': '3daREed4KlrtvohgJjSkJr',
#    'name': 'Hashir',
#    'type': 'artist',
#    'uri': 'spotify:artist:3daREed4KlrtvohgJjSkJr'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LXBFNxqvOcdBVpbgKn6op'},
#    'href': 'https://api.spotify.com/v1/artists/4LXBFNxqvOcdBVpbgKn6op',
#    'id': '4LXBFNxqvOcdBVpbgKn6op',
#    'name': 'iyla',
#    'type': 'artist',
#    'uri': 'spotify:artist:4LXBFNxqvOcdBVpbgKn6op'}],
#  [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7E0jkKhtsnXH3d3k4ibfBW'},
#    'href': 'https://api.spotify.com/v1/artists/7E0jkKhtsnXH3d3k4ibfBW',
#    'id': '7E0jkKhtsnXH3d3k4ibfBW',
#    'name': 'Sucre',
#    'type': 'artist',
#    'uri': 'spotify:artist:7E0jkKhtsnXH3d3k4ibfBW'}]]

# %%
import importlib
importlib.reload(h)
# Out:
# <module 'helpers' from '/mnt/c/Users/aarpe/OneDrive - The University of Chicago/AIMEMS/leyden/spotify_recs/tutorial/helpers.py'>

# %%
def generate_avg_playlist(nsongs:int, batch_size:int=None, user_id:str=None, new_playlist_name:str=None):
    numbered_ml_data = PLC.ml_data.reset_index()
    liked_songs = numbered_ml_data[PLC.ml_likes.reset_index()['like'] == 1]
    liked_song_features = liked_songs.drop(columns=['id', 'name'])
    if batch_size is None:
        batch_size = int(nsongs*0.20)

    # types of features
    features = liked_song_features.columns.to_list()
    int_features = ['duration_ms', 'key', 'mode', 'time_signature', 'tempo', 'loudness']
    float_features = list(set(features) - set(int_features))

    # First filter songs by the Gaussian statistics of the audio features 
    # in liked playlists
    feature_targets = liked_song_features.mean()

    # take feature_min if it is greater than 0, otherwise take 0
    feature_targets.loc[float_features] = feature_targets.loc[float_features
                                                ].apply(lambda x: min(max(x, 0), 1)).round(3)
    feature_targets.loc[int_features] = feature_targets.loc[int_features
                                                        ].round(0)
    feature_targets.loc['time_signature'] = min(feature_targets.loc['time_signature'], 11)
    feature_targets.loc['key'] = min(max(feature_targets.loc['key'], 0), 11)
    feature_targets.loc['mode'] = min(max(feature_targets.loc['mode'], 0), 1)

    feature_targets.index = 'target_' + feature_targets.index
    
    ft_dict = {**feature_targets.loc[feature_targets.index.str.contains(
                                '|'.join(float_features))].to_dict(),
                 **feature_targets.loc[feature_targets.index.str.contains(
                                '|'.join(int_features))].astype(int).to_dict()}

    # Get seed artists, songs, and tracks
    args = {
        'seed_tracks': liked_songs['id'].to_list()[:4],
    }
    
    if 'artist' in liked_songs.keys():
        args['seed_artists'] = liked_songs['artist'].to_list()[:4]
    if 'genre' in liked_songs.keys():
        args['seed_genres'] = liked_songs['genre'].to_list()[:4]

    for key, val in ft_dict.items():
        print(key, val)

    tracks = sp.recommendations(limit=nsongs,
                                **args,
                                **ft_dict
                                )
    
    #print(tracks)
    """playlist = h.Playlist(playlist=tracks)

    if new_playlist_name is not None:
        if user_id is None:
            user_id = client_id
        sp.user_playlist_create(user_id, new_playlist_name, public=False)
        sp.playlist_add_items(playlist_id=playlist.id, items=playlist.track_ids)"""
        
    return tracks

tracks = generate_avg_playlist(10)
tracks
# Out:
# target_acousticness 0.09
# target_danceability 0.823
# target_energy 0.787
# target_instrumentalness 0.001
# target_liveness 0.133
# target_speechiness 0.137
# target_valence 0.656
# target_duration_ms 176282
# target_key 6
# target_loudness -4
# target_mode 1
# target_tempo 112
# target_time_signature 4
# {'tracks': [{'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#       'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#       'id': '64KEffDW9EtZ1y2vBYgq8T',
#       'name': 'Marshmello',
#       'type': 'artist',
#       'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2p4aN0Uxkk3iT3HK0cJ2cJ'},
#       'href': 'https://api.spotify.com/v1/artists/2p4aN0Uxkk3iT3HK0cJ2cJ',
#       'id': '2p4aN0Uxkk3iT3HK0cJ2cJ',
#       'name': 'Tokischa',
#       'type': 'artist',
#       'uri': 'spotify:artist:2p4aN0Uxkk3iT3HK0cJ2cJ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5JsaR3E92H6w32amvOhl7t'},
#     'href': 'https://api.spotify.com/v1/albums/5JsaR3E92H6w32amvOhl7t',
#     'id': '5JsaR3E92H6w32amvOhl7t',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fd462044665308eb7d528d16',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fd462044665308eb7d528d16',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fd462044665308eb7d528d16',
#       'width': 64}],
#     'name': 'ESTILAZO',
#     'release_date': '2022-04-29',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5JsaR3E92H6w32amvOhl7t'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#      'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#      'id': '64KEffDW9EtZ1y2vBYgq8T',
#      'name': 'Marshmello',
#      'type': 'artist',
#      'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2p4aN0Uxkk3iT3HK0cJ2cJ'},
#      'href': 'https://api.spotify.com/v1/artists/2p4aN0Uxkk3iT3HK0cJ2cJ',
#      'id': '2p4aN0Uxkk3iT3HK0cJ2cJ',
#      'name': 'Tokischa',
#      'type': 'artist',
#      'uri': 'spotify:artist:2p4aN0Uxkk3iT3HK0cJ2cJ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 158826,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX92202020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3S6VRZQYwuPIllMmYdAj66'},
#    'href': 'https://api.spotify.com/v1/tracks/3S6VRZQYwuPIllMmYdAj66',
#    'id': '3S6VRZQYwuPIllMmYdAj66',
#    'is_local': False,
#    'name': 'ESTILAZO',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b35af4872accb8ac2a45dc364b22b86e71b2656c?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3S6VRZQYwuPIllMmYdAj66'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#       'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#       'id': '2R21vXR83lH98kGeO99Y66',
#       'name': 'Anuel AA',
#       'type': 'artist',
#       'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6DJslQtfD7mGFGZpfiyrVf'},
#     'href': 'https://api.spotify.com/v1/albums/6DJslQtfD7mGFGZpfiyrVf',
#     'id': '6DJslQtfD7mGFGZpfiyrVf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273015e9561331b4f4fd120271c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02015e9561331b4f4fd120271c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851015e9561331b4f4fd120271c',
#       'width': 64}],
#     'name': 'LLNM2',
#     'release_date': '2022-12-09',
#     'release_date_precision': 'day',
#     'total_tracks': 33,
#     'type': 'album',
#     'uri': 'spotify:album:6DJslQtfD7mGFGZpfiyrVf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2R21vXR83lH98kGeO99Y66'},
#      'href': 'https://api.spotify.com/v1/artists/2R21vXR83lH98kGeO99Y66',
#      'id': '2R21vXR83lH98kGeO99Y66',
#      'name': 'Anuel AA',
#      'type': 'artist',
#      'uri': 'spotify:artist:2R21vXR83lH98kGeO99Y66'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZbuFVK9SeRYrZfQLkNzah'},
#      'href': 'https://api.spotify.com/v1/artists/1ZbuFVK9SeRYrZfQLkNzah',
#      'id': '1ZbuFVK9SeRYrZfQLkNzah',
#      'name': 'Treintisiete',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZbuFVK9SeRYrZfQLkNzah'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ncaw2cfA3Wlly1tBD2eWt'},
#      'href': 'https://api.spotify.com/v1/artists/4ncaw2cfA3Wlly1tBD2eWt',
#      'id': '4ncaw2cfA3Wlly1tBD2eWt',
#      'name': 'Yailin la Mas Viral',
#      'type': 'artist',
#      'uri': 'spotify:artist:4ncaw2cfA3Wlly1tBD2eWt'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 226165,
#    'explicit': True,
#    'external_ids': {'isrc': 'QMDA72266616'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7qgovmYLU3BUltCBdYUPKg'},
#    'href': 'https://api.spotify.com/v1/tracks/7qgovmYLU3BUltCBdYUPKg',
#    'id': '7qgovmYLU3BUltCBdYUPKg',
#    'is_local': False,
#    'name': 'Del Kilo',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c93556fcdf62179a638007890688dfbe4efdd173?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:7qgovmYLU3BUltCBdYUPKg'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MoXcK2GyGg7FIyxPU5yW6'},
#       'href': 'https://api.spotify.com/v1/artists/6MoXcK2GyGg7FIyxPU5yW6',
#       'id': '6MoXcK2GyGg7FIyxPU5yW6',
#       'name': 'SUNMI',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MoXcK2GyGg7FIyxPU5yW6'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3TSX6AxLdCP4E5o3F5jCdN'},
#     'href': 'https://api.spotify.com/v1/albums/3TSX6AxLdCP4E5o3F5jCdN',
#     'id': '3TSX6AxLdCP4E5o3F5jCdN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e33d84e471094fe701f06860',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e33d84e471094fe701f06860',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e33d84e471094fe701f06860',
#       'width': 64}],
#     'name': 'SUNMI SPECIAL EDITION [Gashina]',
#     'release_date': '2017-08-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3TSX6AxLdCP4E5o3F5jCdN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MoXcK2GyGg7FIyxPU5yW6'},
#      'href': 'https://api.spotify.com/v1/artists/6MoXcK2GyGg7FIyxPU5yW6',
#      'id': '6MoXcK2GyGg7FIyxPU5yW6',
#      'name': 'SUNMI',
#      'type': 'artist',
#      'uri': 'spotify:artist:6MoXcK2GyGg7FIyxPU5yW6'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 180000,
#    'explicit': False,
#    'external_ids': {'isrc': 'KRA381702010'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0jFHMDRXxKaREor3hBEEST'},
#    'href': 'https://api.spotify.com/v1/tracks/0jFHMDRXxKaREor3hBEEST',
#    'id': '0jFHMDRXxKaREor3hBEEST',
#    'is_local': False,
#    'name': 'Gashina',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7d768c62349ffacbadbd86eedacd95676d873f27?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0jFHMDRXxKaREor3hBEEST'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LFFf4EpKn2krneZ9vozyz'},
#       'href': 'https://api.spotify.com/v1/artists/3LFFf4EpKn2krneZ9vozyz',
#       'id': '3LFFf4EpKn2krneZ9vozyz',
#       'name': 'JO YURI',
#       'type': 'artist',
#       'uri': 'spotify:artist:3LFFf4EpKn2krneZ9vozyz'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2WCMmZ8vXBnkVp97PzLeoA'},
#     'href': 'https://api.spotify.com/v1/albums/2WCMmZ8vXBnkVp97PzLeoA',
#     'id': '2WCMmZ8vXBnkVp97PzLeoA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273351ac6effa17d7780a306d24',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02351ac6effa17d7780a306d24',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851351ac6effa17d7780a306d24',
#       'width': 64}],
#     'name': 'GLASSY',
#     'release_date': '2021-10-07',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:2WCMmZ8vXBnkVp97PzLeoA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LFFf4EpKn2krneZ9vozyz'},
#      'href': 'https://api.spotify.com/v1/artists/3LFFf4EpKn2krneZ9vozyz',
#      'id': '3LFFf4EpKn2krneZ9vozyz',
#      'name': 'JO YURI',
#      'type': 'artist',
#      'uri': 'spotify:artist:3LFFf4EpKn2krneZ9vozyz'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 189933,
#    'explicit': False,
#    'external_ids': {'isrc': 'KRA492101033'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6PFfx4sEBWPuFqFB0mgX1D'},
#    'href': 'https://api.spotify.com/v1/tracks/6PFfx4sEBWPuFqFB0mgX1D',
#    'id': '6PFfx4sEBWPuFqFB0mgX1D',
#    'is_local': False,
#    'name': 'GLASSY',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3b52b5a4fce6e64881cd51691489361290c3adc2?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6PFfx4sEBWPuFqFB0mgX1D'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xS8cfsAaFyy188dNJGDbM'},
#       'href': 'https://api.spotify.com/v1/artists/5xS8cfsAaFyy188dNJGDbM',
#       'id': '5xS8cfsAaFyy188dNJGDbM',
#       'name': 'Ela Taubert',
#       'type': 'artist',
#       'uri': 'spotify:artist:5xS8cfsAaFyy188dNJGDbM'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/60ljXbrvvWXfuvPen2K319'},
#     'href': 'https://api.spotify.com/v1/albums/60ljXbrvvWXfuvPen2K319',
#     'id': '60ljXbrvvWXfuvPen2K319',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a851c06856e432952280e831',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a851c06856e432952280e831',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a851c06856e432952280e831',
#       'width': 64}],
#     'name': '¿Cómo Pasó?',
#     'release_date': '2024-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:60ljXbrvvWXfuvPen2K319'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5xS8cfsAaFyy188dNJGDbM'},
#      'href': 'https://api.spotify.com/v1/artists/5xS8cfsAaFyy188dNJGDbM',
#      'id': '5xS8cfsAaFyy188dNJGDbM',
#      'name': 'Ela Taubert',
#      'type': 'artist',
#      'uri': 'spotify:artist:5xS8cfsAaFyy188dNJGDbM'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 174546,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72400711'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7slBlaUuSCgADZBuTQDYBB'},
#    'href': 'https://api.spotify.com/v1/tracks/7slBlaUuSCgADZBuTQDYBB',
#    'id': '7slBlaUuSCgADZBuTQDYBB',
#    'is_local': False,
#    'name': '¿Cómo Pasó?',
#    'popularity': 78,
#    'preview_url': None,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7slBlaUuSCgADZBuTQDYBB'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/52zMTJCKluDlFwMQWmccY7'},
#       'href': 'https://api.spotify.com/v1/artists/52zMTJCKluDlFwMQWmccY7',
#       'id': '52zMTJCKluDlFwMQWmccY7',
#       'name': 'LOONA',
#       'type': 'artist',
#       'uri': 'spotify:artist:52zMTJCKluDlFwMQWmccY7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3OOqAsk58Xv8DHu1gRGtaC'},
#     'href': 'https://api.spotify.com/v1/albums/3OOqAsk58Xv8DHu1gRGtaC',
#     'id': '3OOqAsk58Xv8DHu1gRGtaC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c985aeaeccb1db38dddf2986',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c985aeaeccb1db38dddf2986',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c985aeaeccb1db38dddf2986',
#       'width': 64}],
#     'name': '[#]',
#     'release_date': '2020-02-05',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:3OOqAsk58Xv8DHu1gRGtaC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/52zMTJCKluDlFwMQWmccY7'},
#      'href': 'https://api.spotify.com/v1/artists/52zMTJCKluDlFwMQWmccY7',
#      'id': '52zMTJCKluDlFwMQWmccY7',
#      'name': 'LOONA',
#      'type': 'artist',
#      'uri': 'spotify:artist:52zMTJCKluDlFwMQWmccY7'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 195680,
#    'explicit': False,
#    'external_ids': {'isrc': 'KRA382000127'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5l8Vpgx92aqAuniKsSKbyZ'},
#    'href': 'https://api.spotify.com/v1/tracks/5l8Vpgx92aqAuniKsSKbyZ',
#    'id': '5l8Vpgx92aqAuniKsSKbyZ',
#    'is_local': False,
#    'name': 'Oh (Yes I Am)',
#    'popularity': 35,
#    'preview_url': 'https://p.scdn.co/mp3-preview/600b998fd3149eb44e43c1645f38f7b716b010ba?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5l8Vpgx92aqAuniKsSKbyZ'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VwDG9aBflQupaFNjUru9A'},
#       'href': 'https://api.spotify.com/v1/artists/1VwDG9aBflQupaFNjUru9A',
#       'id': '1VwDG9aBflQupaFNjUru9A',
#       'name': 'NAYEON',
#       'type': 'artist',
#       'uri': 'spotify:artist:1VwDG9aBflQupaFNjUru9A'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0wqjfojWuTcbEvwaizvTMw'},
#     'href': 'https://api.spotify.com/v1/albums/0wqjfojWuTcbEvwaizvTMw',
#     'id': '0wqjfojWuTcbEvwaizvTMw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735fb4a9cfbeb3b7beb337ed02',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025fb4a9cfbeb3b7beb337ed02',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515fb4a9cfbeb3b7beb337ed02',
#       'width': 64}],
#     'name': 'IM NAYEON',
#     'release_date': '2022-06-24',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:0wqjfojWuTcbEvwaizvTMw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1VwDG9aBflQupaFNjUru9A'},
#      'href': 'https://api.spotify.com/v1/artists/1VwDG9aBflQupaFNjUru9A',
#      'id': '1VwDG9aBflQupaFNjUru9A',
#      'name': 'NAYEON',
#      'type': 'artist',
#      'uri': 'spotify:artist:1VwDG9aBflQupaFNjUru9A'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/40zyx4iztMjRbIIoI802r4'},
#      'href': 'https://api.spotify.com/v1/artists/40zyx4iztMjRbIIoI802r4',
#      'id': '40zyx4iztMjRbIIoI802r4',
#      'name': 'Felix (Stray Kids)',
#      'type': 'artist',
#      'uri': 'spotify:artist:40zyx4iztMjRbIIoI802r4'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 196160,
#    'explicit': False,
#    'external_ids': {'isrc': 'US5TA2200042'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4zHvWi4iFAG45lgiN7smLC'},
#    'href': 'https://api.spotify.com/v1/tracks/4zHvWi4iFAG45lgiN7smLC',
#    'id': '4zHvWi4iFAG45lgiN7smLC',
#    'is_local': False,
#    'name': 'NO PROBLEM (Feat. Felix of Stray Kids)',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/49f2ff0ec9dba4f2e75bd1726e862267c9d96f55?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4zHvWi4iFAG45lgiN7smLC'},
#   {'album': {'album_type': 'ALBUM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#       'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#       'id': '1mcTU81TzQhprhouKaTkpq',
#       'name': 'Rauw Alejandro',
#       'type': 'artist',
#       'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5AcRssiG0Zqu3lqYW7hMoM'},
#     'href': 'https://api.spotify.com/v1/albums/5AcRssiG0Zqu3lqYW7hMoM',
#     'id': '5AcRssiG0Zqu3lqYW7hMoM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27377ca8a929a08890cb6c8691c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0277ca8a929a08890cb6c8691c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485177ca8a929a08890cb6c8691c',
#       'width': 64}],
#     'name': 'SATURNO',
#     'release_date': '2023-01-24',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:5AcRssiG0Zqu3lqYW7hMoM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1mcTU81TzQhprhouKaTkpq'},
#      'href': 'https://api.spotify.com/v1/artists/1mcTU81TzQhprhouKaTkpq',
#      'id': '1mcTU81TzQhprhouKaTkpq',
#      'name': 'Rauw Alejandro',
#      'type': 'artist',
#      'uri': 'spotify:artist:1mcTU81TzQhprhouKaTkpq'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3z26llYP0dIzgnmUp2vSAw'},
#      'href': 'https://api.spotify.com/v1/artists/3z26llYP0dIzgnmUp2vSAw',
#      'id': '3z26llYP0dIzgnmUp2vSAw',
#      'name': 'Chris Palace',
#      'type': 'artist',
#      'uri': 'spotify:artist:3z26llYP0dIzgnmUp2vSAw'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 207932,
#    'explicit': True,
#    'external_ids': {'isrc': 'USSD12201163'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6glF8OLZEE2AHVu5YtOoiu'},
#    'href': 'https://api.spotify.com/v1/tracks/6glF8OLZEE2AHVu5YtOoiu',
#    'id': '6glF8OLZEE2AHVu5YtOoiu',
#    'is_local': False,
#    'name': 'GATAS',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9245011f8522f1636e977bfbc1ef364843d0dcfc?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6glF8OLZEE2AHVu5YtOoiu'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62T5PGHWJ9sxP2SJq20IHq'},
#       'href': 'https://api.spotify.com/v1/artists/62T5PGHWJ9sxP2SJq20IHq',
#       'id': '62T5PGHWJ9sxP2SJq20IHq',
#       'name': 'PURPLE KISS',
#       'type': 'artist',
#       'uri': 'spotify:artist:62T5PGHWJ9sxP2SJq20IHq'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4uIqXyViDoMKFuuw12kYMO'},
#     'href': 'https://api.spotify.com/v1/albums/4uIqXyViDoMKFuuw12kYMO',
#     'id': '4uIqXyViDoMKFuuw12kYMO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d0a630ea925711a258bb3c93',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d0a630ea925711a258bb3c93',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d0a630ea925711a258bb3c93',
#       'width': 64}],
#     'name': 'Cabin Fever',
#     'release_date': '2023-02-15',
#     'release_date_precision': 'day',
#     'total_tracks': 6,
#     'type': 'album',
#     'uri': 'spotify:album:4uIqXyViDoMKFuuw12kYMO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62T5PGHWJ9sxP2SJq20IHq'},
#      'href': 'https://api.spotify.com/v1/artists/62T5PGHWJ9sxP2SJq20IHq',
#      'id': '62T5PGHWJ9sxP2SJq20IHq',
#      'name': 'PURPLE KISS',
#      'type': 'artist',
#      'uri': 'spotify:artist:62T5PGHWJ9sxP2SJq20IHq'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 192653,
#    'explicit': False,
#    'external_ids': {'isrc': 'KRA382300770'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2th6UWbfVz3hsSDzQAKqy2'},
#    'href': 'https://api.spotify.com/v1/tracks/2th6UWbfVz3hsSDzQAKqy2',
#    'id': '2th6UWbfVz3hsSDzQAKqy2',
#    'is_local': False,
#    'name': 'Sweet Juice',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8a0be48e1c82b93afe74cc8c6b2f43581a53c10b?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2th6UWbfVz3hsSDzQAKqy2'},
#   {'album': {'album_type': 'SINGLE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TEK9tIkcoxib4GxT3O4ky'},
#       'href': 'https://api.spotify.com/v1/artists/4TEK9tIkcoxib4GxT3O4ky',
#       'id': '4TEK9tIkcoxib4GxT3O4ky',
#       'name': 'KISS OF LIFE',
#       'type': 'artist',
#       'uri': 'spotify:artist:4TEK9tIkcoxib4GxT3O4ky'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1HfTA0xDoZ0mswFO3GB3ef'},
#     'href': 'https://api.spotify.com/v1/albums/1HfTA0xDoZ0mswFO3GB3ef',
#     'id': '1HfTA0xDoZ0mswFO3GB3ef',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27307568782625b85282541394b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0207568782625b85282541394b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485107568782625b85282541394b',
#       'width': 64}],
#     'name': 'Midas Touch',
#     'release_date': '2024-04-03',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:1HfTA0xDoZ0mswFO3GB3ef'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4TEK9tIkcoxib4GxT3O4ky'},
#      'href': 'https://api.spotify.com/v1/artists/4TEK9tIkcoxib4GxT3O4ky',
#      'id': '4TEK9tIkcoxib4GxT3O4ky',
#      'name': 'KISS OF LIFE',
#      'type': 'artist',
#      'uri': 'spotify:artist:4TEK9tIkcoxib4GxT3O4ky'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 162880,
#    'explicit': False,
#    'external_ids': {'isrc': 'KRA382401544'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0vaxYDAuAO1nPolC6bQp7V'},
#    'href': 'https://api.spotify.com/v1/tracks/0vaxYDAuAO1nPolC6bQp7V',
#    'id': '0vaxYDAuAO1nPolC6bQp7V',
#    'is_local': False,
#    'name': 'Midas Touch',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7415d33b40129332a3ae7162a94894cef6e18170?cid=2f5154902122464985cd93ea1d10cedb',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0vaxYDAuAO1nPolC6bQp7V'}],
#  'seeds': [{'initialPoolSize': 500,
#    'afterFilteringSize': 313,
#    'afterRelinkingSize': 313,
#    'id': '5awNIWVrh2ISfvPd5IUZNh',
#    'type': 'TRACK',
#    'href': 'https://api.spotify.com/v1/tracks/5awNIWVrh2ISfvPd5IUZNh'},
#   {'initialPoolSize': 508,
#    'afterFilteringSize': 313,
#    'afterRelinkingSize': 313,
#    'id': '65497v9jzFfu5sSA8ADap5',
#    'type': 'TRACK',
#    'href': 'https://api.spotify.com/v1/tracks/65497v9jzFfu5sSA8ADap5'},
#   {'initialPoolSize': 505,
#    'afterFilteringSize': 313,
#    'afterRelinkingSize': 313,
#    'id': '7I0vl97TYZW86qYdgcD1qu',
#    'type': 'TRACK',
#    'href': 'https://api.spotify.com/v1/tracks/7I0vl97TYZW86qYdgcD1qu'},
#   {'initialPoolSize': 501,
#    'afterFilteringSize': 313,
#    'afterRelinkingSize': 313,
#    'id': '7dMTCS9BLzBqYTlAuHP8TM',
#    'type': 'TRACK',
#    'href': 'https://api.spotify.com/v1/tracks/7dMTCS9BLzBqYTlAuHP8TM'}]}

# %%
tracks['tracks'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
def generate_gaussian_playlist(nsongs:int, batch_size:int=None):
    numbered_ml_data = PLC.ml_data.reset_index()
    liked_songs = numbered_ml_data[PLC.ml_likes.reset_index()['like'] == 1]
    liked_song_features = liked_songs.drop(columns=['id', 'name'])
    if batch_size is None:
        batch_size = int(nsongs*0.20)

    # 'popularity',
    # types of features
    features = liked_song_features.columns.to_list()
    int_features = ['duration_ms', 'key', 'mode', 'time_signature', 'tempo', 'loudness']
    float_features = list(set(features) - set(int_features))

    # First filter songs by the Gaussian statistics of the audio features 
    # in liked playlists
    feature_mins = liked_song_features.mean() - liked_song_features.std()
    feature_maxs = liked_song_features.mean() + liked_song_features.std()

    # take feature_min if it is greater than 0, otherwise take 0
    feature_mins.loc[float_features] = feature_mins.loc[float_features
                                                        ].apply(lambda x: max(x, 0)).round(3)
    feature_mins.loc[int_features] = feature_mins.loc[int_features
                                                        ].round(0)
    feature_mins.loc['time_signature'] = min(feature_mins.loc['time_signature'], 11)
    feature_mins.loc['key'] = max(feature_mins.loc['key'], 0)
    feature_mins.loc['mode'] = max(feature_mins.loc['mode'], 0)

    # take feature_min if it is less than 1, otherwise take 1
    feature_maxs.loc[float_features] = feature_maxs.loc[float_features
                                                        ].apply(lambda x: min(x, 1)).round(3)
    feature_maxs.loc[int_features] = feature_maxs.loc[int_features
                                                        ].round(0)
    feature_maxs.loc['key'] = min(feature_maxs.loc['key'], 11)
    feature_maxs.loc['mode'] = min(feature_maxs.loc['mode'], 1)

    feature_mins.index = 'min_' + feature_mins.index
    feature_maxs.index = 'max_' + feature_maxs.index
    
    fmin_dict = {**feature_mins.loc[feature_mins.index.str.contains('|'.join(float_features))].to_dict(),
                 **feature_mins.loc[feature_mins.index.str.contains('|'.join(int_features))].astype(int).to_dict()}
    fmax_dict = {**feature_maxs.loc[feature_maxs.index.str.contains('|'.join(float_features))].to_dict(),
                 **feature_maxs.loc[feature_maxs.index.str.contains('|'.join(int_features))].astype(int).to_dict()}

    # Get seed artists, songs, and tracks
    args = {
        'seed_tracks': liked_songs['id'].to_list()[:4],
    }
    
    if 'artist' in liked_songs.keys():
        args['seed_artists'] = liked_songs['artist'].to_list()[:4]
    if 'genre' in liked_songs.keys():
        args['seed_genres'] = liked_songs['genre'].to_list()[:4]

    for key, val in fmin_dict.items():
        print(key, val)

    for key, val in fmax_dict.items():
        print(key, val)

    tracks = sp.recommendations(limit=nsongs,
                                **args,
                                **fmin_dict,
                                **fmax_dict)
    return tracks

tracks = generate_gaussian_playlist(10)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/recommendations with Params: {'limit': 10, 'min_acousticness': 0.0, 'max_acousticness': 0.229, 'min_danceability': 0.747, 'max_danceability': 0.899, 'min_duration_ms': 143141, 'max_duration_ms': 209424, 'min_energy': 0.689, 'max_energy': 0.884, 'min_instrumentalness': 0.0, 'max_instrumentalness': 0.007, 'min_key': 3, 'max_key': 10, 'min_liveness': 0.034, 'max_liveness': 0.231, 'min_loudness': -5, 'max_loudness': -3, 'min_mode': 0, 'max_mode': 1, 'min_speechiness': 0.054, 'max_speechiness': 0.22, 'min_tempo': 91, 'max_tempo': 134, 'min_time_signature': 4, 'max_time_signature': 4, 'min_valence': 0.49, 'max_valence': 0.822} returned 400 due to invalid request
# min_acousticness 0.0
# min_danceability 0.747
# min_energy 0.689
# min_instrumentalness 0.0
# min_liveness 0.034
# min_speechiness 0.054
# min_valence 0.49
# min_duration_ms 143141
# min_key 3
# min_loudness -5
# min_mode 0
# min_tempo 91
# min_time_signature 4
# max_acousticness 0.229
# max_danceability 0.899
# max_energy 0.884
# max_instrumentalness 0.007
# max_liveness 0.231
# max_speechiness 0.22
# max_valence 0.822
# max_duration_ms 209424
# max_key 10
# max_loudness -3
# max_mode 1
# max_tempo 134
# max_time_signature 4
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/spotipy/client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/recommendations?limit=10&min_acousticness=0.0&max_acousticness=0.229&min_danceability=0.747&max_danceability=0.899&min_duration_ms=143141&max_duration_ms=209424&min_energy=0.689&max_energy=0.884&min_instrumentalness=0.0&max_instrumentalness=0.007&min_key=3&max_key=10&min_liveness=0.034&max_liveness=0.231&min_loudness=-5&max_loudness=-3&min_mode=0&max_mode=1&min_speechiness=0.054&max_speechiness=0.22&min_tempo=91&max_tempo=134&min_time_signature=4&max_time_signature=4&min_valence=0.49&max_valence=0.822
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[38], line 66
#      60     tracks = sp.recommendations(limit=nsongs,
#      61                                 **args,
#      62                                 **fmin_dict,
#      63                                 **fmax_dict)
#      64     return tracks
# ---> 66 tracks = generate_gaussian_playlist(10)
#
# Cell In[38], line 60, in generate_gaussian_playlist(nsongs, batch_size)
#      57 for key, val in fmax_dict.items():
#      58     print(key, val)
# ---> 60 tracks = sp.recommendations(limit=nsongs,
#      61                             **args,
#      62                             **fmin_dict,
#      63                             **fmax_dict)
#      64 return tracks
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/spotipy/client.py:1712, in Spotify.recommendations(self, seed_artists, seed_genres, seed_tracks, limit, country, **kwargs)
#    1710         if param in kwargs:
#    1711             params[param] = kwargs[param]
# -> 1712 return self._get("recommendations", **params)
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/spotipy/client.py:293, in Spotify._internal_call(self, method, url, payload, params)
#     286         reason = None
#     288     logger.error(
#     289         'HTTP Error for %s to %s with Params: %s returned %s due to %s',
#     290         method, url, args.get("params"), response.status_code, msg
#     291     )
# --> 293     raise SpotifyException(
#     294         response.status_code,
#     295         -1,
#     296         "%s:\n %s" % (response.url, msg),
#     297         reason=reason,
#     298         headers=response.headers,
#     299     )
#     300 except requests.exceptions.RetryError as retry_error:
#     301     request = retry_error.request
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/recommendations?limit=10&min_acousticness=0.0&max_acousticness=0.229&min_danceability=0.747&max_danceability=0.899&min_duration_ms=143141&max_duration_ms=209424&min_energy=0.689&max_energy=0.884&min_instrumentalness=0.0&max_instrumentalness=0.007&min_key=3&max_key=10&min_liveness=0.034&max_liveness=0.231&min_loudness=-5&max_loudness=-3&min_mode=0&max_mode=1&min_speechiness=0.054&max_speechiness=0.22&min_tempo=91&max_tempo=134&min_time_signature=4&max_time_signature=4&min_valence=0.49&max_valence=0.822:
#  invalid request, reason: None

# %%
tracks = generate_gaussian_playlist(20)
tracks
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ValueError: could not convert string to float: 'PTT (Paint The Town)Sistema De PatioBack DoorXT4S1SPING PONGMY BAGBIG MADShut DownBIZCOCHITOGet Into It (Yuh)Boss Bitch212Run BTSMirror MirrorWomanBest Friend (feat. Doja Cat, Jamie & CHANMINA) [Remix]ANTIFRAGILENOBODY LIKE YOUBulletproof - Tiborg RemixSweatProblem'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 tracks = generate_gaussian_playlist(20)
#       2 tracks
#
# Cell In[14], line 10, in generate_gaussian_playlist(nsongs, batch_size)
#       6     batch_size = int(nsongs*0.20)
#       8 # First filter songs by the Gaussian statistics of the audio features
#       9 # in liked playlists
# ---> 10 feature_mins = liked_songs.mean() - liked_songs.std()
#      11 feature_maxs = liked_songs.mean() + liked_songs.std()
#      13 feature_mins.index = 'min_' + feature_mins.index
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/frame.py:10524, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10520     df = df.T
#   10522 # After possibly _get_data and transposing, we are now in the
#   10523 #  simple case where we can use BlockManager.reduce
# > 10524 res = df._mgr.reduce(blk_func)
#   10525 out = df._constructor(res).iloc[0]
#   10526 if out_dtype is not None:
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/frame.py:10487, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10485     return values._reduce(name, skipna=skipna, **kwds)
#   10486 else:
# > 10487     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~/mambaforge/envs/rf-spot/lib/python3.11/site-packages/pandas/core/nanops.py:1686, in _ensure_numeric(x)
#    1683         x = x.astype(np.float64)
#    1684     except ValueError as err:
#    1685         # GH#29941 we get here with object arrays containing strs
# -> 1686         raise TypeError(f"Could not convert {x} to numeric") from err
#    1687 else:
#    1688     if not np.any(np.imag(x)):
#
# TypeError: Could not convert ['PTT (Paint The Town)Sistema De PatioBack DoorXT4S1SPING PONGMY BAGBIG MADShut DownBIZCOCHITOGet Into It (Yuh)Boss Bitch212Run BTSMirror MirrorWomanBest Friend (feat. Doja Cat, Jamie & CHANMINA) [Remix]ANTIFRAGILENOBODY LIKE YOUBulletproof - Tiborg RemixSweatProblem'] to numeric

# %% [markdown]
# ## Scratch

# %%
for dt in rf_classifier.estimators_:

    n_nodes = dt.tree_.node_count
    children_left = dt.tree_.children_left
    children_right = dt.tree_.children_right
    feature = dt.tree_.feature
    threshold = dt.tree_.threshold

    node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
    is_leaves = np.zeros(shape=n_nodes, dtype=bool)
    stack = [(0, 0)]  # start with the root node id (0) and its depth (0)
    while len(stack) > 0:
        # `pop` ensures each node is only visited once
        node_id, depth = stack.pop()
        node_depth[node_id] = depth

        # If the left and right child of a node is not the same we have a split
        # node
        is_split_node = children_left[node_id] != children_right[node_id]
        # If a split node, append left and right children and depth to `stack`
        # so we can loop through them
        if is_split_node:
            stack.append((children_left[node_id], depth + 1))
            stack.append((children_right[node_id], depth + 1))
        else:
            is_leaves[node_id] = True

    print(
        "The binary tree structure has {n} nodes and has "
        "the following tree structure:\n".format(n=n_nodes)
    )
    for i in range(n_nodes):
        if is_leaves[i]:
            print(
                "{space}node={node} is a leaf node.".format(
                    space=node_depth[i] * "\t", node=i
                )
            )
        else:
            print(
                "{space}node={node} is a split node: "
                "go to node {left} if X[:, {feature}] <= {threshold} "
                "else to node {right}.".format(
                    space=node_depth[i] * "\t",
                    node=i,
                    left=children_left[i],
                    feature=feature[i],
                    threshold=threshold[i],
                    right=children_right[i],
                )
            )
# Out:
# The binary tree structure has 7 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 9] <= 0.07660000026226044 else to node 4.
# 	node=1 is a split node: go to node 2 if X[:, 3] <= 0.6875 else to node 3.
# 		node=2 is a leaf node.
# 		node=3 is a leaf node.
# 	node=4 is a split node: go to node 5 if X[:, 6] <= 0.096950002014637 else to node 6.
# 		node=5 is a leaf node.
# 		node=6 is a leaf node.
# The binary tree structure has 7 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 9] <= 0.056050000712275505 else to node 4.
# 	node=1 is a split node: go to node 2 if X[:, 0] <= 0.021585000562481582 else to node 3.
# 		node=2 is a leaf node.
# 		node=3 is a leaf node.
# 	node=4 is a split node: go to node 5 if X[:, 4] <= 0.35689999908208847 else to node 6.
# 		node=5 is a leaf node.
# 		node=6 is a leaf node.
# The binary tree structure has 7 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 9] <= 0.056050000712275505 else to node 4.
# 	node=1 is a split node: go to node 2 if X[:, 7] <= -5.350499868392944 else to node 3.
# 		node=2 is a leaf node.
# 		node=3 is a leaf node.
# 	node=4 is a split node: go to node 5 if X[:, 3] <= 0.6620000004768372 else to node 6.
# 		node=5 is a leaf node.
# 		node=6 is a leaf node.
# The binary tree structure has 5 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 10] <= 132.0175018310547 else to node 4.
# 	node=1 is a split node: go to node 2 if X[:, 9] <= 0.044350000098347664 else to node 3.
# 		node=2 is a leaf node.
# 		node=3 is a leaf node.
# 	node=4 is a leaf node.
# The binary tree structure has 5 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 7] <= -5.5295000076293945 else to node 2.
# 	node=1 is a leaf node.
# 	node=2 is a split node: go to node 3 if X[:, 2] <= 226706.5 else to node 4.
# 		node=3 is a leaf node.
# 		node=4 is a leaf node.
# The binary tree structure has 5 nodes and has the following tree structure:
#
# node=0 is a split node: go to node 1 if X[:, 0] <= 0.26250000298023224 else to node 4.
# 	node=1 is a split node: go to node 2 if X[:, 9] <= 0.05525000020861626 else to node 3.
# 		node=2 is a leaf node.
# 		node=3 is a leaf node.
# 	node=4 is a leaf node.
